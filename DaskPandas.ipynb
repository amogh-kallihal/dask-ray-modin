# %%
import os

os.environ["MODIN_ENGINE"] = "dask"  # Modin will use Dask
from distributed import Client
client = Client(memory_limit='8GB')
import modin.pandas as pd
# Out:
# UserWarning: The Dask Engine for Modin is experimental.

# %%
import pandas as old_pd

# %%
# %time loans_df = pd.read_csv("data/kiva_loans.csv")
loans_df.head()
# Out:
# CPU times: user 636 ms, sys: 338 ms, total: 974 ms
# Wall time: 2.39 s
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
#          region currency  partner_id                posted_time  \
# 0        Lahore      PKR       247.0  2014-01-01 06:12:39+00:00
# 1        Lahore      PKR       247.0  2014-01-01 06:51:08+00:00
# 2     Maynaguri      INR       334.0  2014-01-01 09:58:07+00:00
# 3        Lahore      PKR       247.0  2014-01-01 08:03:11+00:00
# 4  Abdul Hakeem      PKR       245.0  2014-01-01 11:53:19+00:00
#
#               disbursed_time                funded_time  term_in_months  \
# 0  2013-12-17 08:00:00+00:00  2014-01-02 10:06:32+00:00            12.0
# 1  2013-12-17 08:00:00+00:00  2014-01-02 09:17:23+00:00            11.0
# 2  2013-12-17 08:00:00+00:00  2014-01-01 16:01:36+00:00            43.0
# 3  2013-12-24 08:00:00+00:00  2014-01-01 13:00:00+00:00            11.0
# 4  2013-12-17 08:00:00+00:00  2014-01-01 19:18:51+00:00            14.0
#
#    lender_count                          tags borrower_genders  \
# 0            12                           NaN           female
# 1            14                           NaN   female, female
# 2             6  user_favorite, user_favorite           female
# 3             8                           NaN           female
# 4            16                           NaN           female
#
#   repayment_interval        date
# 0          irregular  2014-01-01
# 1          irregular  2014-01-01
# 2             bullet  2014-01-01
# 3          irregular  2014-01-01
# 4            monthly  2014-01-01

# %%
# %time locations_df = pd.read_csv("data/kiva_mpi_region_locations.csv")
# Out:
# CPU times: user 50.3 ms, sys: 9.46 ms, total: 59.8 ms
# Wall time: 68.3 ms

# %%
# %time loan_theme_df = pd.read_csv("data/loan_theme_ids.csv")
# Out:
# CPU times: user 73.2 ms, sys: 28.4 ms, total: 102 ms
# Wall time: 207 ms

# %%
loans_df.dtypes
# Out:
# id                      int64
# funded_amount         float64
# loan_amount           float64
# activity               object
# sector                 object
# use                    object
# country_code           object
# country                object
# region                 object
# currency               object
# partner_id            float64
# posted_time            object
# disbursed_time         object
# funded_time            object
# term_in_months        float64
# lender_count            int64
# tags                   object
# borrower_genders       object
# repayment_interval     object
# date                   object
# dtype: object

# %%
locations_df.head()
# Out:
#               LocationName  ISO      country      region world_region    MPI  \
# 0  Badakhshan, Afghanistan  AFG  Afghanistan  Badakhshan   South Asia  0.387
# 1     Badghis, Afghanistan  AFG  Afghanistan     Badghis   South Asia  0.466
# 2     Baghlan, Afghanistan  AFG  Afghanistan     Baghlan   South Asia  0.300
# 3       Balkh, Afghanistan  AFG  Afghanistan       Balkh   South Asia  0.301
# 4      Bamyan, Afghanistan  AFG  Afghanistan      Bamyan   South Asia  0.325
#
#                                geo        lat        lon
# 0  (36.7347725, 70.81199529999999)  36.734772  70.811995
# 1         (35.1671339, 63.7695384)  35.167134  63.769538
# 2         (35.8042947, 69.2877535)  35.804295  69.287754
# 3         (36.7550603, 66.8975372)  36.755060  66.897537
# 4         (34.8100067, 67.8212104)  34.810007  67.821210

# %%
loan_theme_df.head()
# Out:
#        id    Loan Theme ID          Loan Theme Type  Partner ID
# 0  638631  a1050000000skGl                  General       151.0
# 1  640322  a1050000000skGl                  General       151.0
# 2  641006  a1050000002X1ij         Higher Education       160.0
# 3  641019  a1050000002X1ij         Higher Education       160.0
# 4  641594  a1050000002VbsW  Subsistence Agriculture       336.0

# %%
# %time old_loans_df = old_pd.read_csv("data/kiva_loans.csv")
# Out:
# CPU times: user 3.1 s, sys: 221 ms, total: 3.32 s
# Wall time: 3.27 s

# %%
# %time  old_locations_df = old_pd.read_csv("data/kiva_mpi_region_locations.csv")
# Out:
# CPU times: user 7.45 ms, sys: 4.43 ms, total: 11.9 ms
# Wall time: 10.3 ms

# %%
# %time  parking_df = pd.read_csv('data/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv')
# Out:
# CPU times: user 2.95 s, sys: 2.57 s, total: 5.52 s
# Wall time: 41.1 s

# %%
parking_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-083391a6b9ce> in <module>
# ----> 1 parking_df.dtypes
#
# NameError: name 'parking_df' is not defined

# %%
# %time old_parking_df = old_pd.read_csv('data/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv')
# Out:
# DtypeWarning: Columns (17,18,20,21,22,23,29,30,31,32,36,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:62365 remote=tcp://127.0.0.1:62326>
# CPU times: user 46.7 s, sys: 7.63 s, total: 54.3 s
# Wall time: 54.5 s
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:62367 remote=tcp://127.0.0.1:62326>

# %%
import numpy as np

# %% [markdown]
# ***Append Operations ***

# %%
# %time new_df2 = loans_df.append(loans_df)
# Out:
# CPU times: user 5.44 ms, sys: 3.72 ms, total: 9.16 ms
# Wall time: 7.72 ms

# %%
# %time new_df1 = old_loans_df.append(old_loans_df)
# Out:
# CPU times: user 615 ms, sys: 88.3 ms, total: 704 ms
# Wall time: 699 ms

# %%
# %time parking_df.head()
# Out:
# CPU times: user 2.74 ms, sys: 2.56 ms, total: 5.3 ms
# Wall time: 7.25 ms
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              46              SUBN         AUDI              P         37250
# 1              46               VAN         FORD              P         37290
# 2              46               P-U        CHEVR              P         37030
# 3              46               VAN         FORD              P         37270
# 4              41              TRLR          GMC              P         37240
#
#    ...  Hydrant Violation  Double Parking Violation  Latitude  Longitude  \
# 0  ...                NaN                       NaN       NaN        NaN
# 1  ...                NaN                       NaN       NaN        NaN
# 2  ...                NaN                       NaN       NaN        NaN
# 3  ...                NaN                       NaN       NaN        NaN
# 4  ...                NaN                       NaN       NaN        NaN
#
#    Community Board  Community Council   Census Tract  BIN  BBL  NTA
# 0              NaN                 NaN           NaN  NaN  NaN  NaN
# 1              NaN                 NaN           NaN  NaN  NaN  NaN
# 2              NaN                 NaN           NaN  NaN  NaN  NaN
# 3              NaN                 NaN           NaN  NaN  NaN  NaN
# 4              NaN                 NaN           NaN  NaN  NaN  NaN
#
# [5 rows x 51 columns]

# %%
# %time old_parking_df.head()
# Out:
# CPU times: user 268 µs, sys: 31 µs, total: 299 µs
# Wall time: 282 µs
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              46              SUBN         AUDI              P         37250
# 1              46               VAN         FORD              P         37290
# 2              46               P-U        CHEVR              P         37030
# 3              46               VAN         FORD              P         37270
# 4              41              TRLR          GMC              P         37240
#
#    ...  Hydrant Violation  Double Parking Violation  Latitude  Longitude  \
# 0  ...                NaN                       NaN       NaN        NaN
# 1  ...                NaN                       NaN       NaN        NaN
# 2  ...                NaN                       NaN       NaN        NaN
# 3  ...                NaN                       NaN       NaN        NaN
# 4  ...                NaN                       NaN       NaN        NaN
#
#    Community Board  Community Council   Census Tract BIN BBL NTA
# 0              NaN                 NaN           NaN NaN NaN NaN
# 1              NaN                 NaN           NaN NaN NaN NaN
# 2              NaN                 NaN           NaN NaN NaN NaN
# 3              NaN                 NaN           NaN NaN NaN NaN
# 4              NaN                 NaN           NaN NaN NaN NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# ***Concat Operations ***

# %%
# %time df = pd.concat([loans_df for _ in range(5)])
# Out:
# CPU times: user 6.83 ms, sys: 1.02 ms, total: 7.85 ms
# Wall time: 6.24 ms

# %%
# %time df1 = old_pd.concat([old_loans_df for _ in range(5)])
# Out:
# CPU times: user 1.64 s, sys: 278 ms, total: 1.91 s
# Wall time: 1.91 s

# %%
loans_df.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
#          region currency  partner_id                posted_time  \
# 0        Lahore      PKR       247.0  2014-01-01 06:12:39+00:00
# 1        Lahore      PKR       247.0  2014-01-01 06:51:08+00:00
# 2     Maynaguri      INR       334.0  2014-01-01 09:58:07+00:00
# 3        Lahore      PKR       247.0  2014-01-01 08:03:11+00:00
# 4  Abdul Hakeem      PKR       245.0  2014-01-01 11:53:19+00:00
#
#               disbursed_time                funded_time  term_in_months  \
# 0  2013-12-17 08:00:00+00:00  2014-01-02 10:06:32+00:00            12.0
# 1  2013-12-17 08:00:00+00:00  2014-01-02 09:17:23+00:00            11.0
# 2  2013-12-17 08:00:00+00:00  2014-01-01 16:01:36+00:00            43.0
# 3  2013-12-24 08:00:00+00:00  2014-01-01 13:00:00+00:00            11.0
# 4  2013-12-17 08:00:00+00:00  2014-01-01 19:18:51+00:00            14.0
#
#    lender_count                          tags borrower_genders  \
# 0            12                           NaN           female
# 1            14                           NaN   female, female
# 2             6  user_favorite, user_favorite           female
# 3             8                           NaN           female
# 4            16                           NaN           female
#
#   repayment_interval        date
# 0          irregular  2014-01-01
# 1          irregular  2014-01-01
# 2             bullet  2014-01-01
# 3          irregular  2014-01-01
# 4            monthly  2014-01-01

# %% [markdown]
# ***SUM OPERATIONS ***

# %%
# %time loans_df['lender_count'].sum()
# Out:
# CPU times: user 40.1 ms, sys: 4.13 ms, total: 44.2 ms
# Wall time: 157 ms
# 13820730

# %%
# %time old_loans_df['lender_count'].sum()
# Out:
# CPU times: user 1.26 ms, sys: 516 µs, total: 1.77 ms
# Wall time: 926 µs
# 13820730

# %%
# %time parking_df['Summons Number'].sum()
# Out:
# CPU times: user 160 ms, sys: 29.8 ms, total: 190 ms
# Wall time: 3.11 s
# 59029018174512679

# %%
# %time old_parking_df['Summons Number'].sum()
# Out:
# CPU times: user 18.4 ms, sys: 59.3 ms, total: 77.7 ms
# Wall time: 87.8 ms
# 59029018174512679

# %% [markdown]
# ***MEAN OPERATIONS ***

# %%
# %time loans_df.groupby('country').mean()
# Out:
# UserWarning: Large object of size 3.24 MB detected in task graph:
#   (0, <function BasePandasFrame._build_mapreduce_fun ... -d62eae611dd4')
# Consider scattering large objects ahead of time
# with client.scatter to reduce scheduler burden and
# keep data on workers
#
#     future = client.submit(func, big_data)    # bad
#
#     big_future = client.scatter(big_data)     # good
#     future = client.submit(func, big_future)  # good
# CPU times: user 1.04 s, sys: 53.1 ms, total: 1.09 s
# Wall time: 3.12 s
#                           id  funded_amount  loan_amount  partner_id  \
# country
# Afghanistan     9.145775e+05    7000.000000  7000.000000  412.000000
# Albania         9.464003e+05    1287.487073  1378.748707  239.039297
# Armenia         9.913564e+05    1296.104159  1496.396710  158.777778
# Azerbaijan      8.449189e+05    1387.956298  1485.192802   59.034447
# Belize          7.870861e+05     912.200000   912.200000  273.000000
# ...                      ...            ...          ...         ...
# Vietnam         9.926573e+05    1259.955732  1373.369916  204.428479
# Virgin Islands  1.081654e+06       0.000000  5000.000000         NaN
# Yemen           8.271608e+05     771.325119   812.775616  205.000000
# Zambia          9.967362e+05    1464.221939  1544.228316  255.445153
# Zimbabwe        9.130567e+05     836.074616   854.586019  317.636837
#
#                 term_in_months  lender_count
# country
# Afghanistan           7.000000    256.000000
# Albania              23.869700     42.904343
# Armenia              28.339358     37.140076
# Azerbaijan           16.613368     42.724422
# Belize               51.016000     33.472000
# ...                        ...           ...
# Vietnam              17.623905     37.272987
# Virgin Islands       24.000000      0.000000
# Yemen                17.668396     20.888889
# Zambia               17.780612     47.114796
# Zimbabwe              9.479177     24.975706
#
# [87 rows x 6 columns]

# %%
# %time old_loans_df.groupby('country').mean()
# Out:
# CPU times: user 135 ms, sys: 34.3 ms, total: 169 ms
# Wall time: 166 ms
#                           id  funded_amount  loan_amount  partner_id  \
# country
# Afghanistan     9.145775e+05    7000.000000  7000.000000  412.000000
# Albania         9.464003e+05    1287.487073  1378.748707  239.039297
# Armenia         9.913564e+05    1296.104159  1496.396710  158.777778
# Azerbaijan      8.449189e+05    1387.956298  1485.192802   59.034447
# Belize          7.870861e+05     912.200000   912.200000  273.000000
# ...                      ...            ...          ...         ...
# Vietnam         9.926573e+05    1259.955732  1373.369916  204.428479
# Virgin Islands  1.081654e+06       0.000000  5000.000000         NaN
# Yemen           8.271608e+05     771.325119   812.775616  205.000000
# Zambia          9.967362e+05    1464.221939  1544.228316  255.445153
# Zimbabwe        9.130567e+05     836.074616   854.586019  317.636837
#
#                 term_in_months  lender_count
# country
# Afghanistan           7.000000    256.000000
# Albania              23.869700     42.904343
# Armenia              28.339358     37.140076
# Azerbaijan           16.613368     42.724422
# Belize               51.016000     33.472000
# ...                        ...           ...
# Vietnam              17.623905     37.272987
# Virgin Islands       24.000000      0.000000
# Yemen                17.668396     20.888889
# Zambia               17.780612     47.114796
# Zimbabwe              9.479177     24.975706
#
# [87 rows x 6 columns]

# %%
# %time parking_df.groupby('Vehicle Make').mean()
# Out:
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/modin/pandas/groupby.py in mean(self, *args, **kwargs)
#     158
#     159     def mean(self, *args, **kwargs):
# --> 160         return self._apply_agg_function(lambda df: df.mean(*args, **kwargs))
#     161
#     162     def any(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/modin/pandas/groupby.py in _apply_agg_function(self, f, drop, **kwargs)
#     474         else:
#     475             groupby_qc = self._query_compiler
# --> 476         new_manager = groupby_qc.groupby_agg(by, self._axis, f, self._kwargs, kwargs)
#     477         if self._idx_name is not None and self._as_index:
#     478             new_manager.index.name = self._idx_name
#
# ~/anaconda3/lib/python3.7/site-packages/modin/backends/pandas/query_compiler.py in groupby_agg(self, by, axis, agg_func, groupby_args, agg_args)
#    1262
#    1263         new_modin_frame = self._modin_frame._apply_full_axis(
# -> 1264             axis, lambda df: groupby_agg_builder(df)
#    1265         )
#    1266         return self.__constructor__(new_modin_frame)
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/data.py in _apply_full_axis(self, axis, func, new_index, new_columns, dtypes)
#     852         if new_columns is None:
#     853             new_columns = self._frame_mgr_cls.get_indices(
# --> 854                 1, new_partitions, lambda df: df.columns
#     855             )
#     856         if new_index is None:
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/dask/pandas_on_dask_futures/frame/partition_manager.py in get_indices(cls, axis, partitions, index_func)
#      53                 else []
#      54             )
# ---> 55         new_idx = client.gather(new_idx)
#      56         return new_idx[0].append(new_idx[1:]) if len(new_idx) else new_idx
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1837                 direct=direct,
#    1838                 local_worker=local_worker,
# -> 1839                 asynchronous=asynchronous,
#    1840             )
#    1841
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     754         else:
#     755             return sync(
# --> 756                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     757             )
#     758
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     328     else:
#     329         while not e.is_set():
# --> 330             e.wait(10)
#     331     if error[0]:
#     332         typ, exc, tb = error[0]
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# %time old_parking_df.groupby('Vehicle Make').mean()
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# CPU times: user 4.89 s, sys: 8.72 s, total: 13.6 s
# Wall time: 18.8 s
#               Summons Number  Violation Code  Street Code1  Street Code2  \
# Vehicle Make
# (UPS)           1.357272e+09       20.000000       17570.0       24890.0
# +               1.357657e+09       66.000000       23380.0       21520.0
# ,E/BE           1.356611e+09       46.000000           0.0       40404.0
# .               1.355287e+09       35.333333       26720.0        9450.0
# .ISUZ           1.361280e+09       46.000000       34550.0       10610.0
# ...                      ...             ...           ...           ...
# ZUMA            1.360222e+09       43.200000       23464.0       23740.0
# ZUSU            1.358873e+09       78.000000       37570.0       11710.0
# ZUTK            1.370200e+09       21.000000        9380.0        5680.0
# ZUZUK           1.362352e+09       33.000000       36730.0       12660.0
# `               1.356241e+09       21.000000       36180.0       14030.0
#
#               Street Code3  Vehicle Expiration Date  Violation Location  \
# Vehicle Make
# (UPS)         10210.000000             0.000000e+00           13.000000
# +             21620.000000             0.000000e+00          113.000000
# ,E/BE         40404.000000             2.014101e+07           76.000000
# .             11621.666667             6.710204e+06           23.333333
# .ISUZ         10810.000000             2.015043e+07           14.000000
# ...                    ...                      ...                 ...
# ZUMA          12706.000000             4.028086e+06           46.400000
# ZUSU              0.000000             2.015041e+07           34.000000
# ZUTK           5780.000000             0.000000e+00           72.000000
# ZUZUK         21650.000000             2.014542e+07           31.500000
# `             14080.000000             2.015121e+07           63.000000
#
#               Violation Precinct  Issuer Precinct    Issuer Code  ...  \
# Vehicle Make                                                      ...
# (UPS)                  13.000000        13.000000  923108.000000  ...
# +                     113.000000       171.000000  952421.000000  ...
# ,E/BE                  76.000000        76.000000  931444.000000  ...
# .                      23.333333       137.333333  675508.666667  ...
# .ISUZ                  14.000000       161.000000  953638.000000  ...
# ...                          ...              ...            ...  ...
# ZUMA                   46.400000        30.000000  735122.200000  ...
# ZUSU                   34.000000       137.000000  946814.000000  ...
# ZUTK                   72.000000         0.000000  540121.000000  ...
# ZUZUK                  31.500000        96.000000  941606.500000  ...
# `                      63.000000        63.000000  937904.000000  ...
#
#               Hydrant Violation  Double Parking Violation  Latitude  \
# Vehicle Make
# (UPS)                       NaN                       NaN       NaN
# +                           NaN                       NaN       NaN
# ,E/BE                       NaN                       NaN       NaN
# .                           NaN                       NaN       NaN
# .ISUZ                       NaN                       NaN       NaN
# ...                         ...                       ...       ...
# ZUMA                        NaN                       NaN       NaN
# ZUSU                        NaN                       NaN       NaN
# ZUTK                        NaN                       NaN       NaN
# ZUZUK                       NaN                       NaN       NaN
# `                           NaN                       NaN       NaN
#
#               Longitude  Community Board  Community Council   Census Tract  \
# Vehicle Make
# (UPS)               NaN              NaN                 NaN           NaN
# +                   NaN              NaN                 NaN           NaN
# ,E/BE               NaN              NaN                 NaN           NaN
# .                   NaN              NaN                 NaN           NaN
# .ISUZ               NaN              NaN                 NaN           NaN
# ...                 ...              ...                 ...           ...
# ZUMA                NaN              NaN                 NaN           NaN
# ZUSU                NaN              NaN                 NaN           NaN
# ZUTK                NaN              NaN                 NaN           NaN
# ZUZUK               NaN              NaN                 NaN           NaN
# `                   NaN              NaN                 NaN           NaN
#
#               BIN  BBL  NTA
# Vehicle Make
# (UPS)         NaN  NaN  NaN
# +             NaN  NaN  NaN
# ,E/BE         NaN  NaN  NaN
# .             NaN  NaN  NaN
# .ISUZ         NaN  NaN  NaN
# ...           ...  ...  ...
# ZUMA          NaN  NaN  NaN
# ZUSU          NaN  NaN  NaN
# ZUTK          NaN  NaN  NaN
# ZUZUK         NaN  NaN  NaN
# `             NaN  NaN  NaN
#
# [6871 rows x 26 columns]

# %% [markdown]
# ***CSV OPERATIONS ***

# %%
# %time loans_df.to_csv('out.csv', sep='\t')
# Out:
# UserWarning: `DataFrame.to_csv` defaulting to pandas implementation.
# To request implementation, send an email to feature_requests@modin.org.
# UserWarning: Distributing <class 'pandas.core.frame.DataFrame'> object. This may take some time.
# CPU times: user 11.3 s, sys: 1 s, total: 12.3 s
# Wall time: 13.7 s

# %%
# %time old_loans_df.to_csv('out.csv',sep='\t')
# Out:
# CPU times: user 8.07 s, sys: 322 ms, total: 8.39 s
# Wall time: 8.31 s

# %%
# %time parking_df.to_csv('out.csv', sep='\t')
# Out:
# UserWarning: `DataFrame.to_csv` defaulting to pandas implementation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/modin/pandas/base.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, *args, **kwargs)
#    2887             "decimal": decimal,
#    2888         }
# -> 2889         return self._default_to_pandas("to_csv", **kwargs)
#    2890
#    2891     def to_dense(self):  # pragma: no cover
#
# ~/anaconda3/lib/python3.7/site-packages/modin/pandas/base.py in _default_to_pandas(self, op, *args, **kwargs)
#     232             # it on the object after we have converted it to pandas.
#     233             result = getattr(getattr(pandas, self.__name__), op)(
# --> 234                 pandas_obj, *args, **kwargs
#     235             )
#     236         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     200                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     201
# --> 202             self._save()
#     203
#     204         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save(self)
#     322                 break
#     323
# --> 324             self._save_chunk(start_i, end_i)
#     325
#     326     def _save_chunk(self, start_i, end_i):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     338                 decimal=self.decimal,
#     339                 date_format=self.date_format,
# --> 340                 quoting=self.quoting,
#     341             )
#     342
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in to_native_types(self, slicer, na_rep, quoting, **kwargs)
#     757
#     758         if not self.is_object and not quoting:
# --> 759             values = values.astype(str)
#     760         else:
#     761             values = np.array(values, dtype="object")
#
# SystemError: <built-in method item of numpy.ndarray object at 0x204981620> returned a result with an error set

# %%
# %time old_parking_df.to_csv('out.csv', sep='\t')
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# ***MERGE OPERATION ****

# %%
# %time merged_df = pd.merge(loans_df, locations_df, on="country")
# Out:
# UserWarning: `DataFrame.merge` defaulting to pandas implementation.
# CPU times: user 21 s, sys: 5.77 s, total: 26.7 s
# Wall time: 38.2 s

# %%
# %time old_merged_df = old_pd.merge(old_loans_df, old_locations_df, on="country")
# Out:
# CPU times: user 5.21 s, sys: 1.36 s, total: 6.57 s
# Wall time: 6.55 s

# %% [markdown]
# ***IS NULL OPERATION ***

# %%
# %time pd.isnull(loans_df["use"])
# Out:
# CPU times: user 10.2 ms, sys: 13.6 ms, total: 23.8 ms
# Wall time: 41 ms
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 671200    False
# 671201    False
# 671202     True
# 671203    False
# 671204    False
# Name: use, Length: 671205, dtype: bool

# %%
# %time old_pd.isnull(old_loans_df["use"])
# Out:
# CPU times: user 28 ms, sys: 1.02 ms, total: 29 ms
# Wall time: 27.9 ms
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 671200    False
# 671201    False
# 671202     True
# 671203    False
# 671204    False
# Name: use, Length: 671205, dtype: bool

# %%
# %time pd.isnull(parking_df["Meter Number"])
# Out:
# CPU times: user 11.5 ms, sys: 1.59 ms, total: 13.1 ms
# Wall time: 12.4 ms
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 9100273     True
# 9100274     True
# 9100275     True
# 9100276    False
# 9100277     True
# Name: Meter Number, Length: 9100278, dtype: bool

# %%
# %time old_pd.isnull(old_parking_df["Meter Number"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# NameError: name 'old_parking_df' is not defined

# %% [markdown]
# ***Fillna Operation***

# %%
# %time loans_df.fillna(value=0)
# Out:
# CPU times: user 4.09 ms, sys: 1.48 ms, total: 5.56 ms
# Wall time: 4.85 ms
#              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# 1       Transportation  to repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  to purchase an embroidery machine and a variet...
# 4                 Food                           to purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [True, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                                  0
# 671203     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [True, u'to start a turducken farm.'] - this l...
#
#        country_code   country        region currency  partner_id  \
# 0                PK  Pakistan        Lahore      PKR       247.0
# 1                PK  Pakistan        Lahore      PKR       247.0
# 2                IN     India     Maynaguri      INR       334.0
# 3                PK  Pakistan        Lahore      PKR       247.0
# 4                PK  Pakistan  Abdul Hakeem      PKR       245.0
# ...             ...       ...           ...      ...         ...
# 671200           PY  Paraguay    Concepción      USD        58.0
# 671201           KE     Kenya             0      KES       138.0
# 671202           KE     Kenya             0      KES       138.0
# 671203           KE     Kenya             0      KES       138.0
# 671204           KE     Kenya             0      KES       138.0
#
#                       posted_time             disbursed_time  \
# 0       2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1       2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2       2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3       2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4       2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
# ...                           ...                        ...
# 671200  2017-07-25 16:55:34+00:00  2017-07-25 07:00:00+00:00
# 671201  2017-07-25 06:14:08+00:00  2017-07-24 07:00:00+00:00
# 671202  2017-07-26 00:02:07+00:00  2017-07-25 07:00:00+00:00
# 671203  2017-07-26 06:12:55+00:00  2017-07-25 07:00:00+00:00
# 671204  2017-07-26 06:31:46+00:00  2017-07-25 07:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# 0       2014-01-02 10:06:32+00:00            12.0            12
# 1       2014-01-02 09:17:23+00:00            11.0            14
# 2       2014-01-01 16:01:36+00:00            43.0             6
# 3       2014-01-01 13:00:00+00:00            11.0             8
# 4       2014-01-01 19:18:51+00:00            14.0            16
# ...                           ...             ...           ...
# 671200                          0            13.0             0
# 671201  2017-07-26 02:09:43+00:00            13.0             1
# 671202                          0            13.0             0
# 671203                          0            13.0             0
# 671204                          0            13.0             0
#
#                                 tags borrower_genders repayment_interval  \
# 0                                  0           female          irregular
# 1                                  0   female, female          irregular
# 2       user_favorite, user_favorite           female             bullet
# 3                                  0           female          irregular
# 4                                  0           female            monthly
# ...                              ...              ...                ...
# 671200                             0           female            monthly
# 671201                             0           female            monthly
# 671202                             0                0            monthly
# 671203                             0           female            monthly
# 671204                             0           female            monthly
#
#               date
# 0       2014-01-01
# 1       2014-01-01
# 2       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
# ...            ...
# 671200  2017-07-25
# 671201  2017-07-25
# 671202  2017-07-26
# 671203  2017-07-26
# 671204  2017-07-26
#
# [671205 rows x 20 columns]

# %%
# %time old_loans_df.fillna(value=0)
# Out:
# CPU times: user 1.02 s, sys: 99.1 ms, total: 1.11 s
# Wall time: 1.11 s
#              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# 1       Transportation  to repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  to purchase an embroidery machine and a variet...
# 4                 Food                           to purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [True, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                                  0
# 671203     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [True, u'to start a turducken farm.'] - this l...
#
#        country_code   country        region currency  partner_id  \
# 0                PK  Pakistan        Lahore      PKR       247.0
# 1                PK  Pakistan        Lahore      PKR       247.0
# 2                IN     India     Maynaguri      INR       334.0
# 3                PK  Pakistan        Lahore      PKR       247.0
# 4                PK  Pakistan  Abdul Hakeem      PKR       245.0
# ...             ...       ...           ...      ...         ...
# 671200           PY  Paraguay    Concepción      USD        58.0
# 671201           KE     Kenya             0      KES       138.0
# 671202           KE     Kenya             0      KES       138.0
# 671203           KE     Kenya             0      KES       138.0
# 671204           KE     Kenya             0      KES       138.0
#
#                       posted_time             disbursed_time  \
# 0       2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1       2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2       2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3       2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4       2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
# ...                           ...                        ...
# 671200  2017-07-25 16:55:34+00:00  2017-07-25 07:00:00+00:00
# 671201  2017-07-25 06:14:08+00:00  2017-07-24 07:00:00+00:00
# 671202  2017-07-26 00:02:07+00:00  2017-07-25 07:00:00+00:00
# 671203  2017-07-26 06:12:55+00:00  2017-07-25 07:00:00+00:00
# 671204  2017-07-26 06:31:46+00:00  2017-07-25 07:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# 0       2014-01-02 10:06:32+00:00            12.0            12
# 1       2014-01-02 09:17:23+00:00            11.0            14
# 2       2014-01-01 16:01:36+00:00            43.0             6
# 3       2014-01-01 13:00:00+00:00            11.0             8
# 4       2014-01-01 19:18:51+00:00            14.0            16
# ...                           ...             ...           ...
# 671200                          0            13.0             0
# 671201  2017-07-26 02:09:43+00:00            13.0             1
# 671202                          0            13.0             0
# 671203                          0            13.0             0
# 671204                          0            13.0             0
#
#                                 tags borrower_genders repayment_interval  \
# 0                                  0           female          irregular
# 1                                  0   female, female          irregular
# 2       user_favorite, user_favorite           female             bullet
# 3                                  0           female          irregular
# 4                                  0           female            monthly
# ...                              ...              ...                ...
# 671200                             0           female            monthly
# 671201                             0           female            monthly
# 671202                             0                0            monthly
# 671203                             0           female            monthly
# 671204                             0           female            monthly
#
#               date
# 0       2014-01-01
# 1       2014-01-01
# 2       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
# ...            ...
# 671200  2017-07-25
# 671201  2017-07-25
# 671202  2017-07-26
# 671203  2017-07-26
# 671204  2017-07-26
#
# [671205 rows x 20 columns]

# %%
# %time parking_df.fillna(value=0)
# Out:
# CPU times: user 8.83 ms, sys: 1.54 ms, total: 10.4 ms
# Wall time: 9.09 ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-80a0e5970255> in <module>
# ----> 1 get_ipython().run_line_magic('time', 'parking_df.fillna(value=0)')
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/amoghkallihal/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-10> in __call__(self, obj)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     695     """A pprint that just redirects to the normal repr function."""
#     696     # Find newlines and replace them with p.break_()
# --> 697     output = repr(obj)
#     698     for idx,output_line in enumerate(output.splitlines()):
#     699         if idx:
#
# ~/anaconda3/lib/python3.7/site-packages/modin/pandas/dataframe.py in __repr__(self)
#     111
#     112             num_cols += len(self.columns) - i
# --> 113         result = repr(self._build_repr_df(num_rows, num_cols))
#     114         if len(self.index) > num_rows or len(self.columns) > num_cols:
#     115             # The split here is so that we don't repr pandas row lengths.
#
# ~/anaconda3/lib/python3.7/site-packages/modin/pandas/base.py in _build_repr_df(self, num_rows, num_cols)
#      70                 tail_front = pandas.DataFrame()
#      71         else:
# ---> 72             head_front = head.front(num_cols_for_front).to_pandas()
#      73             head_back = head.back(num_cols_for_front).to_pandas()
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/modin/backends/pandas/query_compiler.py in to_pandas(self)
#      55
#      56     def to_pandas(self):
# ---> 57         return self._modin_frame.to_pandas()
#      58
#      59     @classmethod
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/data.py in to_pandas(self)
#    1197             Pandas DataFrame.
#    1198         """
# -> 1199         df = self._frame_mgr_cls.to_pandas(self._partitions)
#    1200         if df.empty:
#    1201             if len(self.columns) != 0:
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/partition_manager.py in to_pandas(cls, partitions)
#     265             A Pandas DataFrame
#     266         """
# --> 267         retrieved_objects = [[obj.to_pandas() for obj in part] for part in partitions]
#     268         if all(
#     269             isinstance(part, pandas.Series) for row in retrieved_objects for part in row
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/partition_manager.py in <listcomp>(.0)
#     265             A Pandas DataFrame
#     266         """
# --> 267         retrieved_objects = [[obj.to_pandas() for obj in part] for part in partitions]
#     268         if all(
#     269             isinstance(part, pandas.Series) for row in retrieved_objects for part in row
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/partition_manager.py in <listcomp>(.0)
#     265             A Pandas DataFrame
#     266         """
# --> 267         retrieved_objects = [[obj.to_pandas() for obj in part] for part in partitions]
#     268         if all(
#     269             isinstance(part, pandas.Series) for row in retrieved_objects for part in row
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/dask/pandas_on_dask_futures/frame/partition.py in to_pandas(self)
#     111             A Pandas DataFrame.
#     112         """
# --> 113         dataframe = self.get()
#     114         assert type(dataframe) is pandas.DataFrame or type(dataframe) is pandas.Series
#     115
#
# ~/anaconda3/lib/python3.7/site-packages/modin/engines/dask/pandas_on_dask_futures/frame/partition.py in get(self)
#      48         if isinstance(self.future, pandas.DataFrame):
#      49             return self.future
# ---> 50         return self.future.result()
#      51
#      52     def apply(self, func, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in result(self, timeout)
#     216
#     217         # shorten error traceback
# --> 218         result = self.client.sync(self._result, callback_timeout=timeout, raiseit=False)
#     219         if self.status == "error":
#     220             typ, exc, tb = result
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     754         else:
#     755             return sync(
# --> 756                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     757             )
#     758
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     328     else:
#     329         while not e.is_set():
# --> 330             e.wait(10)
#     331     if error[0]:
#     332         typ, exc, tb = error[0]
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# %time old_parking_df.fillna(value=0)
